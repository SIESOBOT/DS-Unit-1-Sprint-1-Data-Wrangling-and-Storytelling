# %% [markdown]
# <a href="https://colab.research.google.com/github/SIESOBOT/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/module2-make-features/DS13%20TL-BTR%20BRYAN%20ROSS%201-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
##### Begin Working Here #####

import pandas as pd 
import numpy as np

# %%
#loading the dataset of houses

df = pd.read_csv('https://raw.githubusercontent.com/ryanleeallred/datasets/master/Ames%20Housing%20Data/train.csv')

df.shape
# Out:
# (1460, 81)

# %%
# checking the kind of data we have on the data frame

pd.set_option('display.max_rows', 82)

df.dtypes

# %%
df['Alley'].isnull().value_counts()
# Out:
# True     1369
# False      91
# Name: Alley, dtype: int64

# %%
df['BedroomAbvGr']
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       4
#        ..
# 1455    3
# 1456    3
# 1457    4
# 1458    2
# 1459    3
# Name: BedroomAbvGr, Length: 1460, dtype: int64

# %%
df['LotFrontage']
# Out:
# 0       65.0
# 1       80.0
# 2       68.0
# 3       60.0
# 4       84.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 1460, dtype: float64

# %%
df['MSZoning']
# Out:
# 0       RL
# 1       RL
# 2       RL
# 3       RL
# 4       RL
#         ..
# 1455    RL
# 1456    RL
# 1457    RL
# 1458    RL
# 1459    RL
# Name: MSZoning, Length: 1460, dtype: object

# %%
pd.set_option('display.max_rows', 150)

df['LotFrontage'].value_counts(dropna=False)
# Out:
# NaN      259
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
# 65.0      44
# 85.0      40
# 78.0      25
# 21.0      23
# 90.0      23
# 68.0      19
# 24.0      19
# 64.0      19
# 73.0      18
# 72.0      17
# 79.0      17
# 63.0      17
# 55.0      17
# 100.0     16
# 51.0      15
# 66.0      15
# 74.0      15
# 52.0      14
# 59.0      13
# 71.0      12
# 67.0      12
# 57.0      12
# 82.0      12
# 43.0      12
# 40.0      12
# 76.0      11
# 69.0      11
# 53.0      10
# 92.0      10
# 88.0      10
# 34.0      10
# 86.0      10
# 77.0       9
# 35.0       9
# 44.0       9
# 84.0       9
# 62.0       9
# 93.0       8
# 61.0       8
# 98.0       8
# 96.0       8
# 107.0      7
# 95.0       7
# 120.0      7
# 58.0       7
# 41.0       6
# 105.0      6
# 54.0       6
# 94.0       6
# 48.0       6
# 110.0      6
# 30.0       6
# 89.0       6
# 81.0       6
# 91.0       6
# 36.0       6
# 47.0       5
# 83.0       5
# 37.0       5
# 87.0       5
# ...

# %%
df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
#what is a nan

type(np.nan)
# Out:
# float

# %%
#creating a smaller dataframe out of the principal one 

df_small = df[['TotalBsmtSF','1stFlrSF','2ndFlrSF','SalePrice']].copy()

df_small.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice
# 0          856       856       854     208500
# 1         1262      1262         0     181500
# 2          920       920       866     223500
# 3          756       961       756     140000
# 4         1145      1145      1053     250000

# %%
#Creating a New column(feature) with data we already have 

df_small['TotalSF'] = df_small['1stFlrSF'] + df_small['2ndFlrSF'] + df_small['TotalBsmtSF'] + df_small['SalePrice']

df_small.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSF
# 0          856       856       854     208500   211066
# 1         1262      1262         0     181500   184024
# 2          920       920       866     223500   226206
# 3          756       961       756     140000   142473
# 4         1145      1145      1053     250000   253343

# %%
#dot sintax for calling columns

df_small.TotalSF
# Out:
# 0       211066
# 1       184024
# 2       226206
# 3       142473
# 4       253343
#          ...
# 1455    177600
# 1456    213615
# 1457    269992
# 1458    144281
# 1459    150012
# Name: TotalSF, Length: 1460, dtype: int64

# %%
#bracket syntax for calling columns 

df_small['TotalSF']
# Out:
# 0       211066
# 1       184024
# 2       226206
# 3       142473
# 4       253343
#          ...
# 1455    177600
# 1456    213615
# 1457    269992
# 1458    144281
# 1459    150012
# Name: TotalSF, Length: 1460, dtype: int64

# %%
# creating a new column by dividing the price by square footage

df_small['PricePerSqft'] = df_small['SalePrice'] / df_small['TotalSF']

df_small.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSF  PricePerSqft
# 0          856       856       854     208500   211066      0.987843
# 1         1262      1262         0     181500   184024      0.986284
# 2          920       920       866     223500   226206      0.988037
# 3          756       961       756     140000   142473      0.982642
# 4         1145      1145      1053     250000   253343      0.986804

# %%
#Lending Club data load (this data was loaded thru the GUI of google colab
# since it has issues)
lcdf = pd.read_csv('LoanStats_2018Q4.csv',skiprows=1,skipfooter=2)
print(df.shape)
lcdf.head(10)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
# (1460, 81)
#    id  member_id  ...  settlement_percentage  settlement_term
# 0 NaN        NaN  ...                    NaN              NaN
# 1 NaN        NaN  ...                    NaN              NaN
# 2 NaN        NaN  ...                    NaN              NaN
# 3 NaN        NaN  ...                    NaN              NaN
# 4 NaN        NaN  ...                    NaN              NaN
# 5 NaN        NaN  ...                    NaN              NaN
# 6 NaN        NaN  ...                    NaN              NaN
# 7 NaN        NaN  ...                    NaN              NaN
# 8 NaN        NaN  ...                    NaN              NaN
# 9 NaN        NaN  ...                    NaN              NaN
#
# ...

# %%
lcdf.isnull().sum().sort_values()
# Out:
# inq_fi                                             0
# delinq_amnt                                        0
# chargeoff_within_12_mths                           0
# acc_open_past_24mths                               0
# inq_last_12m                                       0
# total_cu_tl                                        0
# total_rev_hi_lim                                   0
# max_bal_bc                                         0
# open_rv_24m                                        0
# open_rv_12m                                        0
# total_bal_il                                       0
# open_il_24m                                        0
# hardship_flag                                      0
# open_act_il                                        0
# open_acc_6m                                        0
# tot_cur_bal                                        0
# tot_coll_amt                                       0
# acc_now_delinq                                     0
# ...

# %%
#dropping unnesesary columns
lcdf = lcdf.drop(['url','id','member_id','desc'], axis=1)

lcdf.head()
# Out:
#    loan_amnt  funded_amnt  ...  settlement_percentage settlement_term
# 0      35000        35000  ...                    NaN             NaN
# 1       5000         5000  ...                    NaN             NaN
# 2      10000        10000  ...                    NaN             NaN
# 3      17100        17100  ...                    NaN             NaN
# 4       4000         4000  ...                    NaN             NaN
#
# [5 rows x 140 columns]

# %%
#cleaning int_rate column

def int_rate_to_float(cell_contents):
  return float(cell_contents.strip().strip('%'))

# %%
#making sure the function works

numero = ' 15.65%'

int_rate_to_float(numero)
# Out:
# 15.65

# %%
# creating a new columns that has the intrest rate in floats 
lcdf['int_rate_float'] = lcdf['int_rate'].apply(int_rate_to_float)

lcdf.head()
# Out:
#    loan_amnt  funded_amnt  ...  settlement_term int_rate_float
# 0      35000        35000  ...              NaN          14.47
# 1       5000         5000  ...              NaN          22.35
# 2      10000        10000  ...              NaN          23.40
# 3      17100        17100  ...              NaN          18.94
# 4       4000         4000  ...              NaN          10.72
#
# [5 rows x 141 columns]

# %%
#top 20 employement titles

lcdf['emp_title'].value_counts(dropna=False).head(20)
# Out:
# NaN                   20947
# Teacher                2090
# Manager                1773
# Registered Nurse        952
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Truck Driver            387
# Operations Manager      387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %%
#unique employement titles
len(lcdf['emp_title'].value_counts())
# Out:
# 43892

# %%
lcdf['emp_title'].nunique()
# Out:
# 43892

# %%
#how often is there null titles
lcdf['emp_title'].isnull().sum()
# Out:
# 20947

# %%
import numpy as np



examples = ['owner', 'Supervisor', ' Project Manager', np.NaN]

# %%
def clean_title(title):
  if isinstance(title, str):
    return title.strip().title()
  else:
    return "Unknown"
    

cleaned_titles = []
for example in examples:
  cleaned_titles.append(clean_title(example))

cleaned_titles
# Out:
# ['Owner', 'Supervisor', 'Project Manager', 'Unknown']

# %%
[clean_title(title) for title in examples]
# Out:
# ['Owner', 'Supervisor', 'Project Manager', 'Unknown']

# %%
lcdf['emp_title'] = lcdf['emp_title'].apply(clean_title)

lcdf
# Out:
#         loan_amnt  funded_amnt  ...  days_from_credit_to_issue term_int
# 0           35000        35000  ...                       8645       36
# 1            5000         5000  ...                       3197       36
# 2           10000        10000  ...                       4262       60
# 3           17100        17100  ...                       7580       36
# 4            4000         4000  ...                       4474       36
# ...           ...          ...  ...                        ...      ...
# 128407      23000        23000  ...                      12114       36
# 128408      10000        10000  ...                      13241       36
# 128409       5000         5000  ...                       4505       36
# 128410      10000        10000  ...                       3652       36
# 128411      10000        10000  ...                       4413       36
#
# [128412 rows x 145 columns]

# %%
lcdf['emp_title'].isnull().sum()
# Out:
# 0

# %%
[col for col in lcdf if col.endswith('_d')]
# Out:
# ['issue_d', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d']

# %%
lcdf['issue_d'].value_counts()
# Out:
# Oct-2018    46305
# Nov-2018    41973
# Dec-2018    40134
# Name: issue_d, dtype: int64

# %%
lcdf['issue_d'].head()
# Out:
# 0    Dec-2018
# 1    Dec-2018
# 2    Dec-2018
# 3    Dec-2018
# 4    Dec-2018
# Name: issue_d, dtype: object

# %%
lcdf['issue_d'] = pd.to_datetime(lcdf['issue_d'], infer_datetime_format=True)

lcdf.dtypes[:15]
# Out:
# loan_amnt                       int64
# funded_amnt                     int64
# funded_amnt_inv               float64
# term                           object
# int_rate                       object
# installment                   float64
# grade                          object
# sub_grade                      object
# emp_title                      object
# emp_length                     object
# home_ownership                 object
# annual_inc                    float64
# verification_status            object
# issue_d                datetime64[ns]
# loan_status                    object
# dtype: object

# %%
lcdf['issue_d'][0]
# Out:
# Timestamp('2018-12-01 00:00:00')

# %%
lcdf['issue_d'].head().values
# Out:
# array(['2018-12-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
lcdf['issue_d'].dt.year
# Out:
# 0         2018
# 1         2018
# 2         2018
# 3         2018
# 4         2018
#           ...
# 128407    2018
# 128408    2018
# 128409    2018
# 128410    2018
# 128411    2018
# Name: issue_d, Length: 128412, dtype: int64

# %%
lcdf['issue_d'].dt.month
# Out:
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
#           ..
# 128407    10
# 128408    10
# 128409    10
# 128410    10
# 128411    10
# Name: issue_d, Length: 128412, dtype: int64

# %%
lcdf['issue_year'] = lcdf['issue_d'].dt.year
lcdf['issue_month'] = lcdf['issue_d'].dt.month

lcdf.head()
# Out:
#    loan_amnt  funded_amnt  ...  issue_year issue_month
# 0      35000        35000  ...        2018          12
# 1       5000         5000  ...        2018          12
# 2      10000        10000  ...        2018          12
# 3      17100        17100  ...        2018          12
# 4       4000         4000  ...        2018          12
#
# [5 rows x 143 columns]

# %%
lcdf['earliest_cr_line'].head()
# Out:
# 0    Apr-1995
# 1    Mar-2010
# 2    Apr-2007
# 3    Mar-1998
# 4    Sep-2006
# Name: earliest_cr_line, dtype: object

# %%
lcdf['earliest_cr_line'] = pd.to_datetime(lcdf['earliest_cr_line'],infer_datetime_format=True)

# %%
lcdf['days_from_credit_to_issue'] = (lcdf['issue_d'] - lcdf['earliest_cr_line']).dt.days

lcdf['days_from_credit_to_issue'].head()
# Out:
# 0    8645
# 1    3197
# 2    4262
# 3    7580
# 4    4474
# Name: days_from_credit_to_issue, dtype: int64

# %%
lcdf['days_from_credit_to_issue'].describe()
# Out:
# count    128412.000000
# mean       5859.891490
# std        2886.535578
# min        1126.000000
# 25%        4049.000000
# 50%        5266.000000
# 75%        7244.000000
# max       25171.000000
# Name: days_from_credit_to_issue, dtype: float64

# %%
#this column has spacing and also has the word months which makes it a string 
lcdf['term'][0]
# Out:
# ' 36 months'

# %%
# this function will be reusable to convert this into interger
def string_to_int(cell_content):
  return int(cell_content.strip().strip('months'))

# %%
#function works fine!, also added a new column

lcdf['term_int'] = lcdf['term'].apply(string_to_int)

lcdf['term_int'].head(10)
# Out:
# 0    36
# 1    36
# 2    60
# 3    36
# 4    36
# 5    36
# 6    36
# 7    36
# 8    60
# 9    36
# Name: term_int, dtype: int64

# %%
lcdf['loan_status']
# Out:
# 0          Fully Paid
# 1          Fully Paid
# 2             Current
# 3             Current
# 4             Current
#              ...
# 128407    Charged Off
# 128408        Current
# 128409        Current
# 128410        Current
# 128411        Current
# Name: loan_status, Length: 128412, dtype: object

# %%
def loan_stat_inter(content):
  if content == 'Fully paid' or content == 'Current':
    out = 1
  else:
      out = 0

  return out

# %%
lcdf['loan_status'].apply(loan_stat_inter)
# Out:
# 0         0
# 1         0
# 2         1
# 3         1
# 4         1
#          ..
# 128407    0
# 128408    1
# 128409    1
# 128410    1
# 128411    1
# Name: loan_status, Length: 128412, dtype: int64

# %%
#creating a new column to check if the loan status is great

lcdf['loan_status_is_great'] = lcdf['loan_status'].apply(loan_stat_inter)

lcdf.head()
# Out:
#    loan_amnt  funded_amnt  ...  last_pymnt_month loan_status_is_great
# 0      35000        35000  ...               8.0                    0
# 1       5000         5000  ...               7.0                    0
# 2      10000        10000  ...               1.0                    1
# 3      17100        17100  ...               1.0                    1
# 4       4000         4000  ...               1.0                    1
#
# [5 rows x 148 columns]

# %%
#changing the format to date and time

lcdf['last_pymnt_d'] = pd.to_datetime(lcdf['last_pymnt_d'], infer_datetime_format=True)


lcdf['last_pymnt_d'][0]
# Out:
# Timestamp('2019-08-01 00:00:00')

# %%
#creating the last payment montth and year columns 

lcdf['last_pymnt_year'] = lcdf['last_pymnt_d'].dt.year

lcdf['last_pymnt_month'] = lcdf['last_pymnt_d'].dt.month

lcdf.head(10)
# Out:
#    loan_amnt  funded_amnt  ...  last_pymnt_year last_pymnt_month
# 0      35000        35000  ...           2019.0              8.0
# 1       5000         5000  ...           2019.0              7.0
# 2      10000        10000  ...           2020.0              1.0
# 3      17100        17100  ...           2020.0              1.0
# 4       4000         4000  ...           2020.0              1.0
# 5      10475        10475  ...           2020.0              1.0
# 6       7500         7500  ...           2019.0             11.0
# 7       3600         3600  ...           2019.0             12.0
# 8      22000        22000  ...           2020.0              1.0
# 9      10450        10450  ...           2020.0              1.0
#
# [10 rows x 147 columns]

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
